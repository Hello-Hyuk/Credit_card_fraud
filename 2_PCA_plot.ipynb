# %% [markdown]
# ### 깃 연동

# %%
# 소현용
# %cd /content/drive/MyDrive/AI_project/6.Credit_card_fraud/Credit_card_fraud

! git config --global user.email "baeksh.0420@gmail.com"
! git config --global user.name "baeksh0420"
# Out:
# /content/drive/MyDrive/AI_project/6.Credit_card_fraud/Credit_card_fraud

# %%
! git checkout feature/baeksh0420
# Out:
# D	EDA.ipynb
# D	ML_Modeling.ipynb
# Already on 'feature/baeksh0420'
# Your branch is up to date with 'origin/feature/baeksh0420'.

# %%
! git add .

# %%
! git add .
! git commit -m "ML / 3D plot"
! git push
# Out:
# error: open("dataset/val.gsheet"): Operation not supported
# error: unable to index file dataset/val.gsheet
# fatal: adding files failed
# On branch feature/baeksh0420
# Your branch is up to date with 'origin/feature/baeksh0420'.
#
# Changes not staged for commit:
# 	deleted:    EDA.ipynb
# 	deleted:    ML_Modeling.ipynb
#
# Untracked files:
# 	0_EDA.ipynb
# 	1_ML_Modeling.ipynb
# 	2_PCA_plot.ipynb
# 	dataset/val.gsheet
#
# no changes added to commit
# Everything up-to-date

# %% [markdown]
# ## 환경 설정 및 데이터 로드

# %%
# %cd /content/drive/MyDrive/AI_project/6.Credit_card_fraud/Credit_card_fraud
# Out:
# /content/drive/MyDrive/AI_project/6.Credit_card_fraud/Credit_card_fraud
# /content/drive/MyDrive/AI_project/6.Credit_card_fraud/Credit_card_fraud

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import IsolationForest
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.cluster import *

import matplotlib.pyplot as plt

import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import time

import re
import io


import warnings
from mpl_toolkits.mplot3d import Axes3D

warnings.filterwarnings(action='ignore')
#

# %%
train_df = pd.read_csv('dataset/train.csv') # Train
train_df.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0   3 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1   4 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2   6 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3   8 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4   9 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 1  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 2  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 3 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 4  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
#
# ...

# %%
val_df = pd.read_csv('dataset/val.csv') # Validation
val_df.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0  10 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# 1  22  0.962496  0.328461 -0.171479  2.109204  1.129566  1.696038  0.107712
# 2  63  1.145524  0.575068  0.194008  2.598192 -0.092210 -1.044430  0.531588
# 3  69  0.927060 -0.323684  0.387585  0.544474  0.246787  1.650358 -0.427576
# 4  83 -3.005237  2.600138  1.483691 -2.418473  0.306326 -0.824575  2.065426
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.069539 -0.736727  ... -0.633753 -0.120794 -0.385050 -0.069733  0.094199
# 1  0.521502 -1.191311  ...  0.402492 -0.048508 -1.371866  0.390814  0.199964
# 2 -0.241888 -0.896287  ... -0.119703 -0.076510  0.691320  0.633984  0.048741
# 3  0.615371  0.226278  ...  0.079359  0.096632 -0.992569  0.085096  0.377447
# 4 -1.829347  4.009259  ... -0.181268 -0.163747  0.515821  0.136318  0.460054
#
# ...

# %% [markdown]
# ## 모델링

# %% [markdown]
# ### train

# %%
# PCA 적용
from sklearn.decomposition import PCA

train_x = train_df.drop(columns=['ID']) # Input Data
# train_x = train_df.loc[:,["V2", "V4", "V5", "V6", "V7", "V9", "V10", "V11", "V12", "V16", "V17", "V18"]] # 분포비교

pca = PCA(n_components = 3)
pca.fit(train_x)
train_x = pca.transform(train_x)

pd.DataFrame(train_x)
# Out:
#                0          1          2
# 0       4.505435   0.825036   1.461379
# 1       0.596930   1.027944   1.185241
# 2      -1.367485   0.840083   0.270832
# 3      -0.857281   1.075196  -0.345398
# 4       0.062582   1.019570  -0.128945
# ...          ...        ...        ...
# 113837 -1.296339  13.321683 -12.297218
# 113838 -0.506165  -1.975545  -0.667871
# 113839 -1.287088   0.480729  -0.232446
# 113840 -1.404229   0.118675  -0.917219
# 113841 -1.481617  12.534366 -12.830037
#
# [113842 rows x 3 columns]

# %%
len(train_x[:, 0])
# Out:
# 113842

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(train_x[:, 0], train_x[:, 1], train_x[:, 2], marker='o', s=15, cmap='Greens')

# %% [markdown]
# ### val

# %%
# PCA 적용
from sklearn.decomposition import PCA

# val_x = val_df.drop(columns=['ID', 'Class']) # Input Data
val_x = val_df.loc[:,["V2", "V4", "V5", "V6", "V7", "V9", "V10", "V11", "V12", "V16", "V17", "V18"]] # 분포비교

pca = PCA(n_components = 3)
pca.fit(val_x)
val_x = pca.transform(val_x)

pd.DataFrame(val_x)
# Out:
#               0         1         2
# 0     -1.114199 -0.232600 -0.568903
# 1     -0.494745  2.322370 -1.357155
# 2     -0.736087  2.460119  0.750180
# 3      0.272187  0.657989 -0.663054
# 4     -2.681618 -2.490372 -0.419648
# ...         ...       ...       ...
# 28457 -1.486086  0.882514 -0.356261
# 28458 -0.556661 -0.369803 -0.813196
# 28459 -1.363976  0.951183 -0.398608
# 28460  0.152050  0.190822  0.319962
# 28461 -0.526167  0.643388  0.370096
#
# [28462 rows x 3 columns]

# %%
val_idx_1 = val_df[(val_df.Class == 1)].index
print(val_idx_1)

val_x_modify = val_df.iloc[val_idx_1, :]
val_x_modify
# Out:
# Int64Index([   71,   641,   677,   836,  1196,  1201,  1547,  3055,  4039,
#              4267,  4396,  7702,  9326, 12377, 12797, 13706, 14221, 15027,
#             15029, 15030, 15054, 15345, 15425, 24110, 24358, 24742, 25042,
#             25504, 27998, 28146],
#            dtype='int64')
#            ID         V1         V2         V3         V4         V5  \
# 71        624  -3.043541  -3.157307   1.088463   2.288644   1.359805
# 641      6339   0.316459   3.809076  -5.615159   6.047445   1.554026
# 677      6642   0.857321   4.093912  -7.423894   7.380245   0.973366
# 836      8336  -1.426623   4.141986  -9.804103   6.666273  -4.749527
# 1196    12071 -16.367923   9.223692 -23.270631  11.844777  -9.462037
# 1201    12109 -16.917468   9.669900 -23.736443  11.824990  -9.830548
# 1547    15167 -18.474868  11.586381 -21.402917   6.038515 -14.451158
# 3055    30443  -3.896583   4.518355  -4.454027   5.547453  -4.121459
# ...

# %%
fig = plt.figure(figsize=(20, 6))
ax = fig.add_subplot(131, projection='3d')
ax.scatter(val_x[:, 0], val_x[:, 1], val_x[:, 2], c =val_df.Class ,marker='o', s=15, cmap='RdBu')

ax = fig.add_subplot(132, projection='3d')
ax.scatter(val_x[:, 1], val_x[:, 2], val_x[:, 0], c =val_df.Class ,marker='o', s=15, cmap='RdBu')

ax = fig.add_subplot(133, projection='3d')
ax.scatter(val_x[:, 2], val_x[:, 0], val_x[:, 1], c =val_df.Class ,marker='o', s=15, cmap='RdBu')

plt.title("[validation] All")
# Out:
# Text(0.5, 0.92, '[validation] All')

# %%
fig = plt.figure(figsize=(20, 6))
ax = fig.add_subplot(131, projection='3d')
ax.scatter(val_x_modify.iloc[:, 0], val_x_modify.iloc[:, 1], val_x_modify.iloc[:, 2] ,marker='o', s=15, cmap='Blue')

ax = fig.add_subplot(132, projection='3d')
ax.scatter(val_x_modify.iloc[:, 1], val_x_modify.iloc[:, 2], val_x_modify.iloc[:, 0] ,marker='o', s=15, cmap='Blue')

ax = fig.add_subplot(133, projection='3d')
ax.scatter(val_x_modify.iloc[:, 2], val_x_modify.iloc[:, 0], val_x_modify.iloc[:, 1] ,marker='o', s=15, cmap='Blue')

plt.title("[validation] Class1")
# Out:
# Text(0.5, 0.92, '[validation] Class1')
